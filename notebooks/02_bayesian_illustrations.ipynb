# %% [markdown]
# # Bayesian illustrations (synthetic)
#
# Companion to [`docs/bayesian-models.md`](../docs/bayesian-models.md).
#
# This notebook regenerates the educational figures:
# 1. Beta–Binomial prior → posterior
# 2. Logistic calibration diagram
# 3. Bootstrap predictive uncertainty band
#
# **Not clinical evidence.**

# %%
import runpy
from pathlib import Path
from IPython.display import Image, display

ROOT = Path.cwd().resolve()
if not (ROOT / "scripts" / "make_figures.py").exists():
    ROOT = ROOT.parent

runpy.run_path(str(ROOT / "scripts" / "make_figures.py"))
fig = ROOT / "docs" / "figures"
for name in [
    "beta_binomial_prior_posterior.png",
    "logistic_calibration.png",
    "predictive_uncertainty.png",
]:
    display(Image(filename=str(fig / name)))
